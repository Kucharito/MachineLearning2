# %%
import numpy as np
import pandas as pd
import sklearn, sklearn.preprocessing, sklearn.model_selection, sklearn.linear_model, sklearn.metrics, sklearn.feature_selection, sklearn.ensemble
import matplotlib.pyplot as plt
import seaborn as sns

# Numbers display set-up
pd.set_option("display.max_columns", None)
# pd.set_option("display.max_rows", None)
pd.set_option("display.float_format", lambda x: "%.3f" % x)

# %% [markdown]
# # 1) Data Preparation
#
# We are going to use following dataset to train a model for predicting a yearly salary (total compensation) when we are hiring a new employee. This model can help to HR department. Credit to Worksday's tutorial on ML Prague.

# %%
df = pd.read_csv('https://github.com/lowoncuties/VSB-FEI-Machine-Learning-Exercises/raw/main/datasets/ml_08/hr-data.csv')
df.shape
# Out:
# (5000, 24)

# %%
df.head(3)
# Out:
#    compa_ratio  compa_ratio_range                      cost_center  \
# 0        1.545  Above Compa-Ratio  AMER - United States of America
# 1        1.021     At Compa-Ratio  AMER - United States of America
# 2        0.981     At Compa-Ratio        Global Support - Asia/Pac
#
#                     country               current_rating ethnicity  gender  \
# 0  United States of America     4 - Exceeds Expectations     Asian  Female
# 1  United States of America       3 - Meets Expectations     White    Male
# 2               South Korea  5 - Outstanding Performance     Asian    Male
#
#                             generation  high_performer  high_potential  \
# 0             Generation X (1965-1980)           False           False
# 1      Generation Z (1997 and onwards)           False            True
# 2  Generation Y/Millenials (1981-1996)            True           False
#
#   hiring_source  is_leader  is_manager job_family_group job_level  \
# 0      Referral       True        True        Executive        M9
# 1      Referral      False       False      Development        P2
# 2     Recruiter      False       False      Development        P3
#
#                                         job_profile  length_of_service  \
# 0    Executive Management - Chief Executive Officer             26.934
# 1  IT - Product Development - P2 Business Analytics              1.844
# 2      IT - Product Development - P3 Data Scientist              2.192
#
#         location         management_level region         single_job_family  \
# 0  San Francisco  Chief Executive Officer   AMER      Executive Management
# 1       New York   Individual Contributor   AMER  IT - Product Development
# 2          Seoul   Individual Contributor   APAC  IT - Product Development
#
#   tenure_category  total_compensation    age
# 0       15+ Years              772400 57.000
# 1     01-02 Years               68900 25.000
# 2     02-05 Years               53200 33.000

# %%
df.describe(include="all")
# Out:
#         compa_ratio  compa_ratio_range                      cost_center  \
# count      5000.000               5000                             5000
# unique          NaN                  3                                5
# top             NaN  Above Compa-Ratio  AMER - United States of America
# freq            NaN               3284                             1275
# mean          1.169                NaN                              NaN
# std           0.227                NaN                              NaN
# min           0.639                NaN                              NaN
# 25%           0.990                NaN                              NaN
# 50%           1.173                NaN                              NaN
# 75%           1.352                NaN                              NaN
# max           1.645                NaN                              NaN
#
#                          country            current_rating ethnicity  gender  \
# count                       5000                      5000      5000    5000
# unique                         6                         5         5       2
# top     United States of America  4 - Exceeds Expectations     White  Female
# freq                        1275                      1013      2282    2500
# mean                         NaN                       NaN       NaN     NaN
# std                          NaN                       NaN       NaN     NaN
# min                          NaN                       NaN       NaN     NaN
# 25%                          NaN                       NaN       NaN     NaN
# 50%                          NaN                       NaN       NaN     NaN
# 75%                          NaN                       NaN       NaN     NaN
# max                          NaN                       NaN       NaN     NaN
#
#                                  generation high_performer high_potential  \
# count                                  5000           5000           5000
# unique                                    4              2              2
# top     Generation Y/Millenials (1981-1996)          False          False
# freq                                   3364           3992           4227
# mean                                    NaN            NaN            NaN
# std                                     NaN            NaN            NaN
# min                                     NaN            NaN            NaN
# 25%                                     NaN            NaN            NaN
# 50%                                     NaN            NaN            NaN
# 75%                                     NaN            NaN            NaN
# max                                     NaN            NaN            NaN
#
#        hiring_source is_leader is_manager job_family_group job_level  \
# count           5000      5000       5000             5000      5000
# unique             6         2          2                5        13
# top         Referral     False      False      Development        P4
# freq            1531      4674       4409             1476      1334
# mean             NaN       NaN        NaN              NaN       NaN
# std              NaN       NaN        NaN              NaN       NaN
# min              NaN       NaN        NaN              NaN       NaN
# 25%              NaN       NaN        NaN              NaN       NaN
# 50%              NaN       NaN        NaN              NaN       NaN
# 75%              NaN       NaN        NaN              NaN       NaN
# max              NaN       NaN        NaN              NaN       NaN
#
#                                       job_profile  length_of_service  \
# count                                        5000           5000.000
# unique                                         90                NaN
# top     Board Management - Senior Board Associate                NaN
# freq                                          242                NaN
# mean                                          NaN              7.997
# std                                           NaN              7.745
# min                                           NaN              0.003
# 25%                                           NaN              2.595
# 50%                                           NaN              5.699
# 75%                                           NaN             10.648
# max                                           NaN             43.967
#
#              location        management_level region  \
# count            5000                    5000   5000
# unique             19                       6      3
# top     San Francisco  Individual Contributor   AMER
# freq              876                    3913   2515
# mean              NaN                     NaN    NaN
# std               NaN                     NaN    NaN
# min               NaN                     NaN    NaN
# 25%               NaN                     NaN    NaN
# 50%               NaN                     NaN    NaN
# 75%               NaN                     NaN    NaN
# max               NaN                     NaN    NaN
#
#                single_job_family tenure_category  total_compensation      age
# count                       5000            5000            5000.000 5000.000
# unique                        11               6                 NaN      NaN
# top     IT - Product Development     05-10 Years                 NaN      NaN
# freq                        1309            1359                 NaN      NaN
# mean                         NaN             NaN          131567.360   36.859
# std                          NaN             NaN          107949.422   10.741
# min                          NaN             NaN           24600.000   21.000
# 25%                          NaN             NaN           67500.000   29.000
# 50%                          NaN             NaN          104300.000   34.000
# 75%                          NaN             NaN          152700.000   40.000
# max                          NaN             NaN          772400.000   66.000

# %%
df.tenure_category.value_counts().index
# Out:
# Index(['05-10 Years', '02-05 Years', '10-15 Years', '15+ Years', '00-01 Years',
#        '01-02 Years'],
#       dtype='object', name='tenure_category')

# %%
df.replace(np.nan, "nan", regex=True, inplace=True)
categorical_columns = df.select_dtypes(include=["object"]).columns
categorical_columns
# Out:
# Index(['compa_ratio_range', 'cost_center', 'country', 'current_rating',
#        'ethnicity', 'gender', 'generation', 'hiring_source',
#        'job_family_group', 'job_level', 'job_profile', 'location',
#        'management_level', 'region', 'single_job_family', 'tenure_category'],
#       dtype='object')

# %%
ordinal_columns_category_order_dict = {
    'compa_ratio_range': ['Below Compa-Ratio', 'At Compa-Ratio', 'Above Compa-Ratio'],
    'current_rating': ['1 - Unsatisfactory', '2 - Needs Improvement', '3 - Meets Expectations', '4 - Exceeds Expectations', '5 - Outstanding Performance'],
    'tenure_category': ['00-01 Years', '01-02 Years', '02-05 Years', '05-10 Years', '10-15 Years', '15+ Years']
}

# %%
df_encoded = df.select_dtypes(exclude=["object"]).copy()
for col in ['high_performer', 'high_potential', 'is_leader', 'is_manager']:
    df_encoded[col] = df_encoded[col].astype(int)
df_encoded.head()
# Out:
#    compa_ratio  high_performer  high_potential  is_leader  is_manager  \
# 0        1.545               0               0          1           1
# 1        1.021               0               1          0           0
# 2        0.981               1               0          0           0
# 3        1.342               0               1          0           0
# 4        1.290               0               0          0           0
#
#    length_of_service  total_compensation    age
# 0             26.934              772400 57.000
# 1              1.844               68900 25.000
# 2              2.192               53200 33.000
# 3             18.518              204600 45.000
# 4              1.416               70000 32.000

# %%
ordinal_encoder = sklearn.preprocessing.OrdinalEncoder(categories=[ordinal_columns_category_order_dict[column] for column in ordinal_columns_category_order_dict.keys()])
df_encoded = df_encoded.join(pd.DataFrame(ordinal_encoder.fit_transform(df[ordinal_columns_category_order_dict.keys()]), index=df.index, columns=ordinal_columns_category_order_dict.keys()))
df_encoded.head()
# Out:
#    compa_ratio  high_performer  high_potential  is_leader  is_manager  \
# 0        1.545               0               0          1           1
# 1        1.021               0               1          0           0
# 2        0.981               1               0          0           0
# 3        1.342               0               1          0           0
# 4        1.290               0               0          0           0
#
#    length_of_service  total_compensation    age  compa_ratio_range  \
# 0             26.934              772400 57.000              2.000
# 1              1.844               68900 25.000              1.000
# 2              2.192               53200 33.000              1.000
# 3             18.518              204600 45.000              2.000
# 4              1.416               70000 32.000              2.000
#
#    current_rating  tenure_category
# 0           3.000            5.000
# 1           2.000            1.000
# 2           4.000            2.000
# 3           1.000            5.000
# 4           2.000            1.000

# %%
nominal_columns = [column for column in categorical_columns if column not in ordinal_columns_category_order_dict.keys()]
df_encoded = df_encoded.join(pd.get_dummies(df[nominal_columns], prefix_sep="="))
df_encoded.head()
# Out:
#    compa_ratio  high_performer  high_potential  is_leader  is_manager  \
# 0        1.545               0               0          1           1
# 1        1.021               0               1          0           0
# 2        0.981               1               0          0           0
# 3        1.342               0               1          0           0
# 4        1.290               0               0          0           0
#
#    length_of_service  total_compensation    age  compa_ratio_range  \
# 0             26.934              772400 57.000              2.000
# 1              1.844               68900 25.000              1.000
# 2              2.192               53200 33.000              1.000
# 3             18.518              204600 45.000              2.000
# 4              1.416               70000 32.000              2.000
#
#    current_rating  tenure_category  cost_center=AMER - Canada  \
# 0           3.000            5.000                      False
# 1           2.000            1.000                      False
# 2           4.000            2.000                      False
# 3           1.000            5.000                       True
# 4           2.000            1.000                      False
#
#    cost_center=AMER - United States of America  cost_center=EMEA - France  \
# 0                                         True                      False
# 1                                         True                      False
# 2                                        False                      False
# 3                                        False                      False
# 4                                        False                      False
#
#    cost_center=EMEA - United Kingdom  cost_center=Global Support - Asia/Pac  \
# 0                              False                                  False
# 1                              False                                  False
# 2                              False                                   True
# 3                              False                                  False
# 4                              False                                   True
#
#    country=Canada  country=France  country=Singapore  country=South Korea  \
# 0           False           False              False                False
# 1           False           False              False                False
# 2           False           False              False                 True
# 3            True           False              False                False
# 4           False           False              False                 True
#
#    country=United Kingdom  country=United States of America  \
# 0                   False                              True
# 1                   False                              True
# 2                   False                             False
# 3                   False                             False
# 4                   False                             False
#
#    ethnicity=American Indian or Alaska Native  ethnicity=Asian  \
# 0                                       False             True
# 1                                       False            False
# 2                                       False             True
# 3                                       False             True
# 4                                       False             True
#
#    ethnicity=Black or African American  ethnicity=Hispanic  ethnicity=White  \
# 0                                False               False            False
# 1                                False               False             True
# 2                                False               False            False
# 3                                False               False            False
# 4                                False               False            False
#
#    gender=Female  gender=Male  generation=Baby Boomers (1946-1964)  \
# 0           True        False                                False
# 1          False         True                                False
# 2          False         True                                False
# 3          False         True                                False
# 4           True        False                                False
#
#    generation=Generation X (1965-1980)  \
# 0                                 True
# 1                                False
# 2                                False
# 3                                 True
# 4                                False
#
#    generation=Generation Y/Millenials (1981-1996)  \
# 0                                           False
# 1                                           False
# 2                                            True
# 3                                           False
# 4                                            True
#
#    generation=Generation Z (1997 and onwards)  hiring_source=Agency  \
# 0                                       False                 False
# 1                                        True                 False
# 2                                       False                 False
# 3                                       False                 False
# 4                                       False                 False
#
#    hiring_source=Corporate Website  hiring_source=Internal  \
# 0                            False                   False
# 1                            False                   False
# 2                            False                   False
# 3                            False                   False
# 4                            False                    True
#
#    hiring_source=Linkedin  hiring_source=Recruiter  hiring_source=Referral  \
# 0                   False                    False                    True
# 1                   False                    False                    True
# 2                   False                     True                   False
# 3                    True                    False                   False
# 4                   False                    False                   False
#
#    job_family_group=Development  job_family_group=Executive  \
# 0                         False                        True
# 1                          True                       False
# 2                          True                       False
# 3                         False                        True
# 4                         False                       False
#
#    job_family_group=Finance  job_family_group=Sales  \
# 0                     False                   False
# 1                     False                   False
# 2                     False                   False
# 3                     False                   False
# 4                      True                   False
#
#    job_family_group=Services  job_level=M2  job_level=M3  job_level=M4  \
# 0                      False         False         False         False
# 1                      False         False         False         False
# 2                      False         False         False         False
# 3                      False         False         False         False
# 4                      False         False         False         False
#
#    job_level=M5  job_level=M6  job_level=M7  job_level=M8  job_level=M9  \
# 0         False         False         False         False          True
# 1         False         False         False         False         False
# 2         False         False         False         False         False
# 3         False         False         False         False         False
# 4         False         False         False         False         False
#
#    job_level=P1  job_level=P2  job_level=P3  job_level=P4  job_level=P5  \
# 0         False         False         False         False         False
# 1         False          True         False         False         False
# 2         False         False          True         False         False
# 3         False         False         False         False          True
# 4         False         False          True         False         False
#
#    job_profile=Board Management - Executive Vice President  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    job_profile=Board Management - Principal Board Associate  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    job_profile=Board Management - Senior Board Associate  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    job_profile=Board Management - Vice President  \
# 0                                          False
# 1                                          False
# 2                                          False
# 3                                          False
# 4                                          False
#
#    job_profile=Executive Management - Chief Executive Officer  \
# 0                                               True
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    job_profile=Executive Management - Executive Vice President  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    job_profile=Executive Management - Principal Operations Executive  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                               True
# 4                                              False
#
#    job_profile=Executive Management - Senior Operations Executive  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    job_profile=Executive Management - Vice President  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    job_profile=FA - Accounting - P2 Accounting Settlement Specialist  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    job_profile=FA - Accounting - P2 Finance Analyst  \
# 0                                             False
# 1                                             False
# 2                                             False
# 3                                             False
# 4                                             False
#
#    job_profile=FA - Accounting - P3 Accounting Settlement Specialist  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                               True
#
#    job_profile=FA - Accounting - P3 Finance Analyst  \
# 0                                             False
# 1                                             False
# 2                                             False
# 3                                             False
# 4                                             False
#
#    job_profile=FA - Accounting - Principal Accounting Settlement Specialist  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    job_profile=FA - Accounting - Principal Finance Analyst  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    job_profile=FA - Accounting - Senior Accounting Settlement Specialist  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    job_profile=FA - Accounting - Senior Finance Analyst  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    job_profile=FA - Management - Associate Manager  \
# 0                                            False
# 1                                            False
# 2                                            False
# 3                                            False
# 4                                            False
#
#    job_profile=FA - Management - Director  \
# 0                                   False
# 1                                   False
# 2                                   False
# 3                                   False
# 4                                   False
#
#    job_profile=FA - Management - Manager  \
# 0                                  False
# 1                                  False
# 2                                  False
# 3                                  False
# 4                                  False
#
#    job_profile=FA - Management - Senior Director  \
# 0                                          False
# 1                                          False
# 2                                          False
# 3                                          False
# 4                                          False
#
#    job_profile=FA - Management - Senior Manager  \
# 0                                         False
# 1                                         False
# 2                                         False
# 3                                         False
# 4                                         False
#
#    job_profile=Human Resources - Associate Manager  \
# 0                                            False
# 1                                            False
# 2                                            False
# 3                                            False
# 4                                            False
#
#    job_profile=Human Resources - Director  \
# 0                                   False
# 1                                   False
# 2                                   False
# 3                                   False
# 4                                   False
#
#    job_profile=Human Resources - Manager  \
# 0                                  False
# 1                                  False
# 2                                  False
# 3                                  False
# 4                                  False
#
#    job_profile=Human Resources - P2 Human Resources Analyst  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    job_profile=Human Resources - P2 Human Resources Consultant  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    job_profile=Human Resources - P3 Human Resources Analyst  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    job_profile=Human Resources - P3 Human Resources Consultant  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    job_profile=Human Resources - Principal Human Resources Analyst  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    job_profile=Human Resources - Principal Human Resources Consultant  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    job_profile=Human Resources - Senior Director  \
# 0                                          False
# 1                                          False
# 2                                          False
# 3                                          False
# 4                                          False
#
#    job_profile=Human Resources - Senior Human Resources Analyst  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    job_profile=Human Resources - Senior Human Resources Consultant  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    job_profile=Human Resources - Senior Manager  \
# 0                                         False
# 1                                         False
# 2                                         False
# 3                                         False
# 4                                         False
#
#    job_profile=Human Resources - Vice President  \
# 0                                         False
# 1                                         False
# 2                                         False
# 3                                         False
# 4                                         False
#
#    job_profile=IT - Product Development - P1 Business Analytics  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    job_profile=IT - Product Development - P1 Data Scientist  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    job_profile=IT - Product Development - P1 QA  \
# 0                                         False
# 1                                         False
# 2                                         False
# 3                                         False
# 4                                         False
#
#    job_profile=IT - Product Development - P1 Software Engineer  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    job_profile=IT - Product Development - P2 Business Analytics  \
# 0                                              False
# 1                                               True
# 2                                              False
# 3                                              False
# 4                                              False
#
#    job_profile=IT - Product Development - P2 Data Scientist  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    job_profile=IT - Product Development - P2 QA  \
# 0                                         False
# 1                                         False
# 2                                         False
# 3                                         False
# 4                                         False
#
#    job_profile=IT - Product Development - P2 Software Engineer  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    job_profile=IT - Product Development - P3 Business Analytics  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    job_profile=IT - Product Development - P3 Data Scientist  \
# 0                                              False
# 1                                              False
# 2                                               True
# 3                                              False
# 4                                              False
#
#    job_profile=IT - Product Development - P3 QA  \
# 0                                         False
# 1                                         False
# 2                                         False
# 3                                         False
# 4                                         False
#
#    job_profile=IT - Product Development - P3 Software Engineer  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    job_profile=IT - Product Development - Principal Business Analytics  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    job_profile=IT - Product Development - Principal Data Scientist  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    job_profile=IT - Product Development - Principal QA  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    job_profile=IT - Product Development - Principal Software Engineer  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    job_profile=IT - Product Development - Senior Business Analytics  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    job_profile=IT - Product Development - Senior Data Scientist  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    job_profile=IT - Product Development - Senior QA  \
# 0                                             False
# 1                                             False
# 2                                             False
# 3                                             False
# 4                                             False
#
#    job_profile=IT - Product Development - Senior Software Engineer  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    job_profile=IT - Product Management - Associate Manager  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    job_profile=IT - Product Management - Director  \
# 0                                           False
# 1                                           False
# 2                                           False
# 3                                           False
# 4                                           False
#
#    job_profile=IT - Product Management - Executive Vice President  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    job_profile=IT - Product Management - Manager  \
# 0                                          False
# 1                                          False
# 2                                          False
# 3                                          False
# 4                                          False
#
#    job_profile=IT - Product Management - Senior Director  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    job_profile=IT - Product Management - Senior Manager  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    job_profile=IT - Product Management - Vice President  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    job_profile=Legal - Corporate - Associate Manager  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    job_profile=Legal - Corporate - Manager  \
# 0                                    False
# 1                                    False
# 2                                    False
# 3                                    False
# 4                                    False
#
#    job_profile=Legal - Corporate - P2 Legal Associate Consultant  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    job_profile=Legal - Corporate - P2 Legal Consultant  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    job_profile=Legal - Corporate - P3 Legal Associate Consultant  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    job_profile=Legal - Corporate - P3 Legal Consultant  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    job_profile=Legal - Corporate - Principal Legal Associate Consultant  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    job_profile=Legal - Corporate - Principal Legal Consultant  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    job_profile=Legal - Corporate - Senior Legal Associate Consultant  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    job_profile=Legal - Corporate - Senior Legal Consultant  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    job_profile=Legal - Corporate - Vice President  \
# 0                                           False
# 1                                           False
# 2                                           False
# 3                                           False
# 4                                           False
#
#    job_profile=Sales - Direct Sales - P1 Direct Sales Representative  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    job_profile=Sales - Direct Sales - P2 Direct Sales Representative  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    job_profile=Sales - Direct Sales - P3 Direct Sales Representative  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    job_profile=Sales - Direct Sales - Principal Direct Sales Representative  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    job_profile=Sales - Direct Sales - Senior Direct Sales Representative  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    job_profile=Sales - Inside Sales - P1 Inside Sales Representative  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    job_profile=Sales - Inside Sales - P2 Inside Sales Representative  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    job_profile=Sales - Inside Sales - P3 Inside Sales Representative  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    job_profile=Sales - Inside Sales - Principal Inside Sales Representative  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    job_profile=Sales - Inside Sales - Senior Inside Sales Representative  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    job_profile=Sales - Management - Associate Manager  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    job_profile=Sales - Management - Director  \
# 0                                      False
# 1                                      False
# 2                                      False
# 3                                      False
# 4                                      False
#
#    job_profile=Sales - Management - Manager  \
# 0                                     False
# 1                                     False
# 2                                     False
# 3                                     False
# 4                                     False
#
#    job_profile=Sales - Management - Senior Director  \
# 0                                             False
# 1                                             False
# 2                                             False
# 3                                             False
# 4                                             False
#
#    job_profile=Sales - Management - Senior Manager  \
# 0                                            False
# 1                                            False
# 2                                            False
# 3                                            False
# 4                                            False
#
#    job_profile=Sales - Management - Vice President  location=Busan  \
# 0                                            False           False
# 1                                            False           False
# 2                                            False           False
# 3                                            False           False
# 4                                            False           False
#
#    location=Calgary  location=Daegu  location=Edmonton  location=Gwangju  \
# 0             False           False              False             False
# 1             False           False              False             False
# 2             False           False              False             False
# 3             False           False              False             False
# 4             False           False              False             False
#
#    location=Incheon  location=London  location=Lyon  location=Marseille  \
# 0             False            False          False               False
# 1             False            False          False               False
# 2             False            False          False               False
# 3             False            False          False               False
# 4             False            False          False               False
#
#    location=Montreal  location=New York  location=Nice  location=Paris  \
# 0              False              False          False           False
# 1              False               True          False           False
# 2              False              False          False           False
# 3              False              False          False           False
# 4              False              False          False           False
#
#    location=San Francisco  location=Seoul  location=Singapore  \
# 0                    True           False               False
# 1                   False           False               False
# 2                   False            True               False
# 3                   False           False               False
# 4                   False            True               False
#
#    location=Toronto  location=Toulouse  location=Vancouver  \
# 0             False              False               False
# 1             False              False               False
# 2             False              False               False
# 3              True              False               False
# 4             False              False               False
#
#    management_level=Chief Executive Officer  management_level=Director  \
# 0                                      True                      False
# 1                                     False                      False
# 2                                     False                      False
# 3                                     False                      False
# 4                                     False                      False
#
#    management_level=Executive Vice President  \
# 0                                      False
# 1                                      False
# 2                                      False
# 3                                       True
# 4                                      False
#
#    management_level=Individual Contributor  management_level=Manager  \
# 0                                    False                     False
# 1                                     True                     False
# 2                                     True                     False
# 3                                    False                     False
# 4                                     True                     False
#
#    management_level=Vice President  region=AMER  region=APAC  region=EMEA  \
# 0                            False         True        False        False
# 1                            False         True        False        False
# 2                            False        False         True        False
# 3                            False         True        False        False
# 4                            False        False         True        False
#
#    single_job_family=Board Management  single_job_family=Executive Management  \
# 0                               False                                    True
# 1                               False                                   False
# 2                               False                                   False
# 3                               False                                    True
# 4                               False                                   False
#
#    single_job_family=FA - Accounting  single_job_family=FA - Management  \
# 0                              False                              False
# 1                              False                              False
# 2                              False                              False
# 3                              False                              False
# 4                               True                              False
#
#    single_job_family=Human Resources  \
# 0                              False
# 1                              False
# 2                              False
# 3                              False
# 4                              False
#
#    single_job_family=IT - Product Development  \
# 0                                       False
# 1                                        True
# 2                                        True
# 3                                       False
# 4                                       False
#
#    single_job_family=IT - Product Management  \
# 0                                      False
# 1                                      False
# 2                                      False
# 3                                      False
# 4                                      False
#
#    single_job_family=Legal - Corporate  \
# 0                                False
# 1                                False
# 2                                False
# 3                                False
# 4                                False
#
#    single_job_family=Sales - Direct Sales  \
# 0                                   False
# 1                                   False
# 2                                   False
# 3                                   False
# 4                                   False
#
#    single_job_family=Sales - Inside Sales  \
# 0                                   False
# 1                                   False
# 2                                   False
# 3                                   False
# 4                                   False
#
#    single_job_family=Sales - Management
# 0                                 False
# 1                                 False
# 2                                 False
# 3                                 False
# 4                                 False

# %%
df_encoded.shape
# Out:
# (5000, 186)

# %% [markdown]
# # 2) Linear Regression

# %% [markdown]
# There are a few assumptions associated with a linear regression model:
#
# * Linearity: The relationship between X and Y is linear.
# * Homoscedasticity: The variance of residual is the same for any value of X.
# * No multicollinearity: There is no high correlations among two or more independent variables.
# * Independence: Observations are independent of each other.
# * Normality: For any fixed value of X, Y is normally distributed.

# %%
X_data = df_encoded.drop('total_compensation', axis=1)
y_data = df_encoded['total_compensation']

X_train, X_test, y_train, y_test = sklearn.model_selection.train_test_split(
    X_data, y_data, test_size=0.20, random_state=12
)
column_names = X_train.columns

# %%
scaler = sklearn.preprocessing.StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
from sklearn.metrics import mean_squared_error

model = sklearn.linear_model.LinearRegression()
model.fit(X_train_scaled, y_train)
y_pred = model.predict(X_test_scaled)
residuals = y_test - y_pred

# Evaluate the model
mse = mean_squared_error(y_test,y_pred)
rmse = np.sqrt(mse)
r2 = sklearn.metrics.r2_score(y_test, y_pred)
mape = sklearn.metrics.mean_absolute_percentage_error(y_test, y_pred)

print("Mean Absolute Percentage Error (MAPE):", mape)
print("Root Mean Squared Error:", rmse)
print("R-squared:", r2)
# Out:
# Mean Absolute Percentage Error (MAPE): 0.0977263316713188
# Root Mean Squared Error: 21758.191135620225
# R-squared: 0.9554837290982976

# %%
residuals.describe()
# Out:
# count      1000.000
# mean        102.796
# std       21768.835
# min     -119501.368
# 25%       -6385.605
# 50%        -958.311
# 75%        6429.234
# max      472615.601
# Name: total_compensation, dtype: float64

# %%
sns.histplot(residuals, kde=True)
# Out:
# <Axes: xlabel='total_compensation', ylabel='Count'>

# %%
# We broke multicollinearity assumption by using all features
plt.figure(figsize=(12, 8))
sns.heatmap(X_train.corr(), annot=False, cmap='RdYlBu', vmin=-1, vmax=1)
plt.title('Correlation matrix')
plt.show()
# NOTE: White line represents columns which contain only zeros

# %% [markdown]
# # 3) Orthogonal Matching Pursuit

# %%
n_coefs = 11
model = sklearn.linear_model.OrthogonalMatchingPursuit(n_nonzero_coefs=n_coefs)
model.fit(X_train_scaled, y_train)
y_pred = model.predict(X_test_scaled)
residuals = y_test - y_pred

# Evaluate the model
mse =  mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = sklearn.metrics.r2_score(y_test, y_pred)
mape = sklearn.metrics.mean_absolute_percentage_error(y_test, y_pred)

print("Mean Absolute Percentage Error (MAPE):", mape)
print("Root Mean Squared Error:", rmse)
print("R-squared:", r2)
# Out:
# Mean Absolute Percentage Error (MAPE): 0.12508973808636561
# Root Mean Squared Error: 25115.23968820701
# R-squared: 0.9406872778959967

# %% [markdown]
# What are the residuals?

# %%
residuals.describe()
# Out:
# count      1000.000
# mean        -71.508
# std       25127.705
# min     -136974.590
# 25%       -9392.462
# 50%       -2249.060
# 75%        6910.988
# max      465699.425
# Name: total_compensation, dtype: float64

# %% [markdown]
# How does the target attribute looks like?

# %%
df['total_compensation'].hist(bins=100)
# Out:
# <Axes: >

# %% [markdown]
# What is the model doing? There is a linear model inside :-).

# %%
y_pred = X_test_scaled @ model.coef_ + model.intercept_
y_pred[:5]
# Out:
# array([40012.98749039, 72509.05456051, 26720.48469275, 74277.72802948,
#        43852.45827751])

# %% [markdown]
# ### Use coefficients estimated by OMP to visualize their impact using (e.g.: seaborn, matplotlib). Think about the interpretation of the visualization, especially "age", "job_level -> M8" and "generation -> Baby Boomers (1946 - 1964)".

# %%
n_coefs = 11
model = sklearn.linear_model.OrthogonalMatchingPursuit(n_nonzero_coefs=n_coefs)
model.fit(X_train_scaled, y_train)
# Out:
# OrthogonalMatchingPursuit(n_nonzero_coefs=11)

# %%
# Visualise the features that have been selected and their respective scores
feature_scores = pd.Series(model.coef_, index=X_data.columns).sort_values(ascending=False, key=lambda x: abs(x))
selected_features = feature_scores[:n_coefs]

f, ax = plt.subplots(figsize=(10, 5))
shades = 31
palette = sns.color_palette('coolwarm', shades)
minmax = np.max([-np.min(selected_features), np.max(selected_features)])
bins = np.linspace(-minmax, minmax, num=shades)
palette_indices = np.digitize(selected_features, bins) - 1
colors = [palette[idx] for idx in palette_indices]

ax = sns.barplot(x=selected_features, y=selected_features.index, palette=colors, dodge=False)
ax.set_yticklabels(selected_features.index)
ax.set_xlabel('Feature impact on prediction')
plt.show()
# Out:
# C:\Users\adamk\AppData\Local\Temp\ipykernel_6212\2638879991.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=selected_features, y=selected_features.index, palette=colors, dodge=False)
# C:\Users\adamk\AppData\Local\Temp\ipykernel_6212\2638879991.py:14: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(selected_features.index)

# %% [markdown]
# #### What you can tell about these features?

# %% [markdown]
# #### Lets see what a one year change in age can do

# %%
X_test.iloc[0:1]
# Out:
#       compa_ratio  high_performer  high_potential  is_leader  is_manager  \
# 4506        0.824               1               0          0           0
#
#       length_of_service    age  compa_ratio_range  current_rating  \
# 4506              4.318 28.000              0.000           4.000
#
#       tenure_category  cost_center=AMER - Canada  \
# 4506            2.000                      False
#
#       cost_center=AMER - United States of America  cost_center=EMEA - France  \
# 4506                                        False                       True
#
#       cost_center=EMEA - United Kingdom  \
# 4506                              False
#
#       cost_center=Global Support - Asia/Pac  country=Canada  country=France  \
# 4506                                  False           False            True
#
#       country=Singapore  country=South Korea  country=United Kingdom  \
# 4506              False                False                   False
#
#       country=United States of America  \
# 4506                             False
#
#       ethnicity=American Indian or Alaska Native  ethnicity=Asian  \
# 4506                                       False            False
#
#       ethnicity=Black or African American  ethnicity=Hispanic  \
# 4506                                False               False
#
#       ethnicity=White  gender=Female  gender=Male  \
# 4506             True          False         True
#
#       generation=Baby Boomers (1946-1964)  \
# 4506                                False
#
#       generation=Generation X (1965-1980)  \
# 4506                                False
#
#       generation=Generation Y/Millenials (1981-1996)  \
# 4506                                            True
#
#       generation=Generation Z (1997 and onwards)  hiring_source=Agency  \
# 4506                                       False                 False
#
#       hiring_source=Corporate Website  hiring_source=Internal  \
# 4506                             True                   False
#
#       hiring_source=Linkedin  hiring_source=Recruiter  hiring_source=Referral  \
# 4506                   False                    False                   False
#
#       job_family_group=Development  job_family_group=Executive  \
# 4506                         False                       False
#
#       job_family_group=Finance  job_family_group=Sales  \
# 4506                     False                    True
#
#       job_family_group=Services  job_level=M2  job_level=M3  job_level=M4  \
# 4506                      False         False         False         False
#
#       job_level=M5  job_level=M6  job_level=M7  job_level=M8  job_level=M9  \
# 4506         False         False         False         False         False
#
#       job_level=P1  job_level=P2  job_level=P3  job_level=P4  job_level=P5  \
# 4506         False          True         False         False         False
#
#       job_profile=Board Management - Executive Vice President  \
# 4506                                              False
#
#       job_profile=Board Management - Principal Board Associate  \
# 4506                                              False
#
#       job_profile=Board Management - Senior Board Associate  \
# 4506                                              False
#
#       job_profile=Board Management - Vice President  \
# 4506                                          False
#
#       job_profile=Executive Management - Chief Executive Officer  \
# 4506                                              False
#
#       job_profile=Executive Management - Executive Vice President  \
# 4506                                              False
#
#       job_profile=Executive Management - Principal Operations Executive  \
# 4506                                              False
#
#       job_profile=Executive Management - Senior Operations Executive  \
# 4506                                              False
#
#       job_profile=Executive Management - Vice President  \
# 4506                                              False
#
#       job_profile=FA - Accounting - P2 Accounting Settlement Specialist  \
# 4506                                              False
#
#       job_profile=FA - Accounting - P2 Finance Analyst  \
# 4506                                             False
#
#       job_profile=FA - Accounting - P3 Accounting Settlement Specialist  \
# 4506                                              False
#
#       job_profile=FA - Accounting - P3 Finance Analyst  \
# 4506                                             False
#
#       job_profile=FA - Accounting - Principal Accounting Settlement Specialist  \
# 4506                                              False
#
#       job_profile=FA - Accounting - Principal Finance Analyst  \
# 4506                                              False
#
#       job_profile=FA - Accounting - Senior Accounting Settlement Specialist  \
# 4506                                              False
#
#       job_profile=FA - Accounting - Senior Finance Analyst  \
# 4506                                              False
#
#       job_profile=FA - Management - Associate Manager  \
# 4506                                            False
#
#       job_profile=FA - Management - Director  \
# 4506                                   False
#
#       job_profile=FA - Management - Manager  \
# 4506                                  False
#
#       job_profile=FA - Management - Senior Director  \
# 4506                                          False
#
#       job_profile=FA - Management - Senior Manager  \
# 4506                                         False
#
#       job_profile=Human Resources - Associate Manager  \
# 4506                                            False
#
#       job_profile=Human Resources - Director  \
# 4506                                   False
#
#       job_profile=Human Resources - Manager  \
# 4506                                  False
#
#       job_profile=Human Resources - P2 Human Resources Analyst  \
# 4506                                              False
#
#       job_profile=Human Resources - P2 Human Resources Consultant  \
# 4506                                              False
#
#       job_profile=Human Resources - P3 Human Resources Analyst  \
# 4506                                              False
#
#       job_profile=Human Resources - P3 Human Resources Consultant  \
# 4506                                              False
#
#       job_profile=Human Resources - Principal Human Resources Analyst  \
# 4506                                              False
#
#       job_profile=Human Resources - Principal Human Resources Consultant  \
# 4506                                              False
#
#       job_profile=Human Resources - Senior Director  \
# 4506                                          False
#
#       job_profile=Human Resources - Senior Human Resources Analyst  \
# 4506                                              False
#
#       job_profile=Human Resources - Senior Human Resources Consultant  \
# 4506                                              False
#
#       job_profile=Human Resources - Senior Manager  \
# 4506                                         False
#
#       job_profile=Human Resources - Vice President  \
# 4506                                         False
#
#       job_profile=IT - Product Development - P1 Business Analytics  \
# 4506                                              False
#
#       job_profile=IT - Product Development - P1 Data Scientist  \
# 4506                                              False
#
#       job_profile=IT - Product Development - P1 QA  \
# 4506                                         False
#
#       job_profile=IT - Product Development - P1 Software Engineer  \
# 4506                                              False
#
#       job_profile=IT - Product Development - P2 Business Analytics  \
# 4506                                              False
#
#       job_profile=IT - Product Development - P2 Data Scientist  \
# 4506                                              False
#
#       job_profile=IT - Product Development - P2 QA  \
# 4506                                         False
#
#       job_profile=IT - Product Development - P2 Software Engineer  \
# 4506                                              False
#
#       job_profile=IT - Product Development - P3 Business Analytics  \
# 4506                                              False
#
#       job_profile=IT - Product Development - P3 Data Scientist  \
# 4506                                              False
#
#       job_profile=IT - Product Development - P3 QA  \
# 4506                                         False
#
#       job_profile=IT - Product Development - P3 Software Engineer  \
# 4506                                              False
#
#       job_profile=IT - Product Development - Principal Business Analytics  \
# 4506                                              False
#
#       job_profile=IT - Product Development - Principal Data Scientist  \
# 4506                                              False
#
#       job_profile=IT - Product Development - Principal QA  \
# 4506                                              False
#
#       job_profile=IT - Product Development - Principal Software Engineer  \
# 4506                                              False
#
#       job_profile=IT - Product Development - Senior Business Analytics  \
# 4506                                              False
#
#       job_profile=IT - Product Development - Senior Data Scientist  \
# 4506                                              False
#
#       job_profile=IT - Product Development - Senior QA  \
# 4506                                             False
#
#       job_profile=IT - Product Development - Senior Software Engineer  \
# 4506                                              False
#
#       job_profile=IT - Product Management - Associate Manager  \
# 4506                                              False
#
#       job_profile=IT - Product Management - Director  \
# 4506                                           False
#
#       job_profile=IT - Product Management - Executive Vice President  \
# 4506                                              False
#
#       job_profile=IT - Product Management - Manager  \
# 4506                                          False
#
#       job_profile=IT - Product Management - Senior Director  \
# 4506                                              False
#
#       job_profile=IT - Product Management - Senior Manager  \
# 4506                                              False
#
#       job_profile=IT - Product Management - Vice President  \
# 4506                                              False
#
#       job_profile=Legal - Corporate - Associate Manager  \
# 4506                                              False
#
#       job_profile=Legal - Corporate - Manager  \
# 4506                                    False
#
#       job_profile=Legal - Corporate - P2 Legal Associate Consultant  \
# 4506                                              False
#
#       job_profile=Legal - Corporate - P2 Legal Consultant  \
# 4506                                              False
#
#       job_profile=Legal - Corporate - P3 Legal Associate Consultant  \
# 4506                                              False
#
#       job_profile=Legal - Corporate - P3 Legal Consultant  \
# 4506                                              False
#
#       job_profile=Legal - Corporate - Principal Legal Associate Consultant  \
# 4506                                              False
#
#       job_profile=Legal - Corporate - Principal Legal Consultant  \
# 4506                                              False
#
#       job_profile=Legal - Corporate - Senior Legal Associate Consultant  \
# 4506                                              False
#
#       job_profile=Legal - Corporate - Senior Legal Consultant  \
# 4506                                              False
#
#       job_profile=Legal - Corporate - Vice President  \
# 4506                                           False
#
#       job_profile=Sales - Direct Sales - P1 Direct Sales Representative  \
# 4506                                              False
#
#       job_profile=Sales - Direct Sales - P2 Direct Sales Representative  \
# 4506                                              False
#
#       job_profile=Sales - Direct Sales - P3 Direct Sales Representative  \
# 4506                                              False
#
#       job_profile=Sales - Direct Sales - Principal Direct Sales Representative  \
# 4506                                              False
#
#       job_profile=Sales - Direct Sales - Senior Direct Sales Representative  \
# 4506                                              False
#
#       job_profile=Sales - Inside Sales - P1 Inside Sales Representative  \
# 4506                                              False
#
#       job_profile=Sales - Inside Sales - P2 Inside Sales Representative  \
# 4506                                               True
#
#       job_profile=Sales - Inside Sales - P3 Inside Sales Representative  \
# 4506                                              False
#
#       job_profile=Sales - Inside Sales - Principal Inside Sales Representative  \
# 4506                                              False
#
#       job_profile=Sales - Inside Sales - Senior Inside Sales Representative  \
# 4506                                              False
#
#       job_profile=Sales - Management - Associate Manager  \
# 4506                                              False
#
#       job_profile=Sales - Management - Director  \
# 4506                                      False
#
#       job_profile=Sales - Management - Manager  \
# 4506                                     False
#
#       job_profile=Sales - Management - Senior Director  \
# 4506                                             False
#
#       job_profile=Sales - Management - Senior Manager  \
# 4506                                            False
#
#       job_profile=Sales - Management - Vice President  location=Busan  \
# 4506                                            False           False
#
#       location=Calgary  location=Daegu  location=Edmonton  location=Gwangju  \
# 4506             False           False              False             False
#
#       location=Incheon  location=London  location=Lyon  location=Marseille  \
# 4506             False            False           True               False
#
#       location=Montreal  location=New York  location=Nice  location=Paris  \
# 4506              False              False          False           False
#
#       location=San Francisco  location=Seoul  location=Singapore  \
# 4506                   False           False               False
#
#       location=Toronto  location=Toulouse  location=Vancouver  \
# 4506             False              False               False
#
#       management_level=Chief Executive Officer  management_level=Director  \
# 4506                                     False                      False
#
#       management_level=Executive Vice President  \
# 4506                                      False
#
#       management_level=Individual Contributor  management_level=Manager  \
# 4506                                     True                     False
#
#       management_level=Vice President  region=AMER  region=APAC  region=EMEA  \
# 4506                            False        False        False         True
#
#       single_job_family=Board Management  \
# 4506                               False
#
#       single_job_family=Executive Management  \
# 4506                                   False
#
#       single_job_family=FA - Accounting  single_job_family=FA - Management  \
# 4506                              False                              False
#
#       single_job_family=Human Resources  \
# 4506                              False
#
#       single_job_family=IT - Product Development  \
# 4506                                       False
#
#       single_job_family=IT - Product Management  \
# 4506                                      False
#
#       single_job_family=Legal - Corporate  \
# 4506                                False
#
#       single_job_family=Sales - Direct Sales  \
# 4506                                   False
#
#       single_job_family=Sales - Inside Sales  \
# 4506                                    True
#
#       single_job_family=Sales - Management
# 4506                                 False

# %%
pd.DataFrame(X_test_scaled[0:1, :], columns=X_test.columns)
# Out:
#    compa_ratio  high_performer  high_potential  is_leader  is_manager  \
# 0       -1.516           1.981          -0.418     -0.266      -0.369
#
#    length_of_service    age  compa_ratio_range  current_rating  \
# 0             -0.473 -0.820             -1.810           1.401
#
#    tenure_category  cost_center=AMER - Canada  \
# 0           -0.439                     -0.574
#
#    cost_center=AMER - United States of America  cost_center=EMEA - France  \
# 0                                       -0.585                      2.319
#
#    cost_center=EMEA - United Kingdom  cost_center=Global Support - Asia/Pac  \
# 0                             -0.418                                 -0.486
#
#    country=Canada  country=France  country=Singapore  country=South Korea  \
# 0          -0.574           2.319             -0.319               -0.331
#
#    country=United Kingdom  country=United States of America  \
# 0                  -0.418                            -0.585
#
#    ethnicity=American Indian or Alaska Native  ethnicity=Asian  \
# 0                                      -0.241           -0.639
#
#    ethnicity=Black or African American  ethnicity=Hispanic  ethnicity=White  \
# 0                               -0.255              -0.395            1.085
#
#    gender=Female  gender=Male  generation=Baby Boomers (1946-1964)  \
# 0         -1.008        1.008                               -0.288
#
#    generation=Generation X (1965-1980)  \
# 0                               -0.427
#
#    generation=Generation Y/Millenials (1981-1996)  \
# 0                                           0.693
#
#    generation=Generation Z (1997 and onwards)  hiring_source=Agency  \
# 0                                      -0.322                -0.328
#
#    hiring_source=Corporate Website  hiring_source=Internal  \
# 0                            2.008                  -0.324
#
#    hiring_source=Linkedin  hiring_source=Recruiter  hiring_source=Referral  \
# 0                  -0.322                   -0.511                  -0.668
#
#    job_family_group=Development  job_family_group=Executive  \
# 0                        -0.653                      -0.400
#
#    job_family_group=Finance  job_family_group=Sales  \
# 0                    -0.415                   1.608
#
#    job_family_group=Services  job_level=M2  job_level=M3  job_level=M4  \
# 0                     -0.399        -0.117        -0.137        -0.122
#
#    job_level=M5  job_level=M6  job_level=M7  job_level=M8  job_level=M9  \
# 0        -0.118        -0.099        -0.113        -0.196         0.000
#
#    job_level=P1  job_level=P2  job_level=P3  job_level=P4  job_level=P5  \
# 0        -0.252         2.392        -0.564        -0.601        -0.444
#
#    job_profile=Board Management - Executive Vice President  \
# 0                                             -0.132
#
#    job_profile=Board Management - Principal Board Associate  \
# 0                                             -0.159
#
#    job_profile=Board Management - Senior Board Associate  \
# 0                                             -0.226
#
#    job_profile=Board Management - Vice President  \
# 0                                         -0.073
#
#    job_profile=Executive Management - Chief Executive Officer  \
# 0                                              0.000
#
#    job_profile=Executive Management - Executive Vice President  \
# 0                                             -0.137
#
#    job_profile=Executive Management - Principal Operations Executive  \
# 0                                             -0.131
#
#    job_profile=Executive Management - Senior Operations Executive  \
# 0                                             -0.069
#
#    job_profile=Executive Management - Vice President  \
# 0                                             -0.050
#
#    job_profile=FA - Accounting - P2 Accounting Settlement Specialist  \
# 0                                             -0.109
#
#    job_profile=FA - Accounting - P2 Finance Analyst  \
# 0                                            -0.113
#
#    job_profile=FA - Accounting - P3 Accounting Settlement Specialist  \
# 0                                             -0.138
#
#    job_profile=FA - Accounting - P3 Finance Analyst  \
# 0                                            -0.138
#
#    job_profile=FA - Accounting - Principal Accounting Settlement Specialist  \
# 0                                             -0.124
#
#    job_profile=FA - Accounting - Principal Finance Analyst  \
# 0                                             -0.132
#
#    job_profile=FA - Accounting - Senior Accounting Settlement Specialist  \
# 0                                             -0.153
#
#    job_profile=FA - Accounting - Senior Finance Analyst  \
# 0                                             -0.145
#
#    job_profile=FA - Management - Associate Manager  \
# 0                                           -0.039
#
#    job_profile=FA - Management - Director  \
# 0                                  -0.045
#
#    job_profile=FA - Management - Manager  \
# 0                                 -0.047
#
#    job_profile=FA - Management - Senior Director  \
# 0                                         -0.047
#
#    job_profile=FA - Management - Senior Manager  \
# 0                                        -0.039
#
#    job_profile=Human Resources - Associate Manager  \
# 0                                           -0.027
#
#    job_profile=Human Resources - Director  \
# 0                                  -0.032
#
#    job_profile=Human Resources - Manager  \
# 0                                 -0.050
#
#    job_profile=Human Resources - P2 Human Resources Analyst  \
# 0                                             -0.084
#
#    job_profile=Human Resources - P2 Human Resources Consultant  \
# 0                                             -0.093
#
#    job_profile=Human Resources - P3 Human Resources Analyst  \
# 0                                             -0.120
#
#    job_profile=Human Resources - P3 Human Resources Consultant  \
# 0                                             -0.119
#
#    job_profile=Human Resources - Principal Human Resources Analyst  \
# 0                                             -0.082
#
#    job_profile=Human Resources - Principal Human Resources Consultant  \
# 0                                             -0.093
#
#    job_profile=Human Resources - Senior Director  \
# 0                                         -0.022
#
#    job_profile=Human Resources - Senior Human Resources Analyst  \
# 0                                             -0.123
#
#    job_profile=Human Resources - Senior Human Resources Consultant  \
# 0                                             -0.119
#
#    job_profile=Human Resources - Senior Manager  \
# 0                                        -0.042
#
#    job_profile=Human Resources - Vice President  \
# 0                                        -0.022
#
#    job_profile=IT - Product Development - P1 Business Analytics  \
# 0                                             -0.119
#
#    job_profile=IT - Product Development - P1 Data Scientist  \
# 0                                             -0.108
#
#    job_profile=IT - Product Development - P1 QA  \
# 0                                        -0.103
#
#    job_profile=IT - Product Development - P1 Software Engineer  \
# 0                                             -0.110
#
#    job_profile=IT - Product Development - P2 Business Analytics  \
# 0                                             -0.118
#
#    job_profile=IT - Product Development - P2 Data Scientist  \
# 0                                             -0.114
#
#    job_profile=IT - Product Development - P2 QA  \
# 0                                        -0.105
#
#    job_profile=IT - Product Development - P2 Software Engineer  \
# 0                                             -0.120
#
#    job_profile=IT - Product Development - P3 Business Analytics  \
# 0                                             -0.155
#
#    job_profile=IT - Product Development - P3 Data Scientist  \
# 0                                             -0.134
#
#    job_profile=IT - Product Development - P3 QA  \
# 0                                        -0.136
#
#    job_profile=IT - Product Development - P3 Software Engineer  \
# 0                                             -0.140
#
#    job_profile=IT - Product Development - Principal Business Analytics  \
# 0                                             -0.085
#
#    job_profile=IT - Product Development - Principal Data Scientist  \
# 0                                             -0.082
#
#    job_profile=IT - Product Development - Principal QA  \
# 0                                             -0.101
#
#    job_profile=IT - Product Development - Principal Software Engineer  \
# 0                                             -0.082
#
#    job_profile=IT - Product Development - Senior Business Analytics  \
# 0                                             -0.122
#
#    job_profile=IT - Product Development - Senior Data Scientist  \
# 0                                             -0.105
#
#    job_profile=IT - Product Development - Senior QA  \
# 0                                            -0.129
#
#    job_profile=IT - Product Development - Senior Software Engineer  \
# 0                                             -0.121
#
#    job_profile=IT - Product Management - Associate Manager  \
# 0                                             -0.073
#
#    job_profile=IT - Product Management - Director  \
# 0                                          -0.078
#
#    job_profile=IT - Product Management - Executive Vice President  \
# 0                                             -0.039
#
#    job_profile=IT - Product Management - Manager  \
# 0                                         -0.087
#
#    job_profile=IT - Product Management - Senior Director  \
# 0                                             -0.063
#
#    job_profile=IT - Product Management - Senior Manager  \
# 0                                             -0.084
#
#    job_profile=IT - Product Management - Vice President  \
# 0                                             -0.042
#
#    job_profile=Legal - Corporate - Associate Manager  \
# 0                                             -0.016
#
#    job_profile=Legal - Corporate - Manager  \
# 0                                   -0.032
#
#    job_profile=Legal - Corporate - P2 Legal Associate Consultant  \
# 0                                             -0.061
#
#    job_profile=Legal - Corporate - P2 Legal Consultant  \
# 0                                             -0.067
#
#    job_profile=Legal - Corporate - P3 Legal Associate Consultant  \
# 0                                             -0.090
#
#    job_profile=Legal - Corporate - P3 Legal Consultant  \
# 0                                             -0.082
#
#    job_profile=Legal - Corporate - Principal Legal Associate Consultant  \
# 0                                             -0.063
#
#    job_profile=Legal - Corporate - Principal Legal Consultant  \
# 0                                             -0.053
#
#    job_profile=Legal - Corporate - Senior Legal Associate Consultant  \
# 0                                             -0.079
#
#    job_profile=Legal - Corporate - Senior Legal Consultant  \
# 0                                             -0.069
#
#    job_profile=Legal - Corporate - Vice President  \
# 0                                          -0.016
#
#    job_profile=Sales - Direct Sales - P1 Direct Sales Representative  \
# 0                                             -0.084
#
#    job_profile=Sales - Direct Sales - P2 Direct Sales Representative  \
# 0                                             -0.155
#
#    job_profile=Sales - Direct Sales - P3 Direct Sales Representative  \
# 0                                             -0.206
#
#    job_profile=Sales - Direct Sales - Principal Direct Sales Representative  \
# 0                                             -0.145
#
#    job_profile=Sales - Direct Sales - Senior Direct Sales Representative  \
# 0                                             -0.195
#
#    job_profile=Sales - Inside Sales - P1 Inside Sales Representative  \
# 0                                             -0.069
#
#    job_profile=Sales - Inside Sales - P2 Inside Sales Representative  \
# 0                                              6.182
#
#    job_profile=Sales - Inside Sales - P3 Inside Sales Representative  \
# 0                                             -0.208
#
#    job_profile=Sales - Inside Sales - Principal Inside Sales Representative  \
# 0                                             -0.133
#
#    job_profile=Sales - Inside Sales - Senior Inside Sales Representative  \
# 0                                             -0.193
#
#    job_profile=Sales - Management - Associate Manager  \
# 0                                             -0.076
#
#    job_profile=Sales - Management - Director  \
# 0                                     -0.069
#
#    job_profile=Sales - Management - Manager  \
# 0                                    -0.073
#
#    job_profile=Sales - Management - Senior Director  \
# 0                                            -0.055
#
#    job_profile=Sales - Management - Senior Manager  \
# 0                                           -0.067
#
#    job_profile=Sales - Management - Vice President  location=Busan  \
# 0                                           -0.047          -0.136
#
#    location=Calgary  location=Daegu  location=Edmonton  location=Gwangju  \
# 0            -0.158          -0.103             -0.117            -0.076
#
#    location=Incheon  location=London  location=Lyon  location=Marseille  \
# 0            -0.090           -0.418          8.317              -0.158
#
#    location=Montreal  location=New York  location=Nice  location=Paris  \
# 0             -0.203             -0.294         -0.090          -0.323
#
#    location=San Francisco  location=Seoul  location=Singapore  \
# 0                  -0.462          -0.244              -0.319
#
#    location=Toronto  location=Toulouse  location=Vancouver  \
# 0            -0.412             -0.128              -0.159
#
#    management_level=Chief Executive Officer  management_level=Director  \
# 0                                     0.000                     -0.158
#
#    management_level=Executive Vice President  \
# 0                                     -0.215
#
#    management_level=Individual Contributor  management_level=Manager  \
# 0                                    0.526                    -0.239
#
#    management_level=Vice President  region=AMER  region=APAC  region=EMEA  \
# 0                           -0.323       -1.006       -0.486        1.507
#
#    single_job_family=Board Management  single_job_family=Executive Management  \
# 0                              -0.325                                  -0.211
#
#    single_job_family=FA - Accounting  single_job_family=FA - Management  \
# 0                             -0.399                             -0.098
#
#    single_job_family=Human Resources  \
# 0                             -0.324
#
#    single_job_family=IT - Product Development  \
# 0                                      -0.602
#
#    single_job_family=IT - Product Management  \
# 0                                     -0.185
#
#    single_job_family=Legal - Corporate  \
# 0                               -0.210
#
#    single_job_family=Sales - Direct Sales  \
# 0                                  -0.384
#
#    single_job_family=Sales - Inside Sales  \
# 0                                   2.646
#
#    single_job_family=Sales - Management
# 0                                -0.162

# %%
X_new_entry = X_test.iloc[0:1].copy()
X_new_entry['age'] += 1

# %%
pd.DataFrame(scaler.transform(X_new_entry), columns=X_test.columns)
# Out:
#    compa_ratio  high_performer  high_potential  is_leader  is_manager  \
# 0       -1.516           1.981          -0.418     -0.266      -0.369
#
#    length_of_service    age  compa_ratio_range  current_rating  \
# 0             -0.473 -0.727             -1.810           1.401
#
#    tenure_category  cost_center=AMER - Canada  \
# 0           -0.439                     -0.574
#
#    cost_center=AMER - United States of America  cost_center=EMEA - France  \
# 0                                       -0.585                      2.319
#
#    cost_center=EMEA - United Kingdom  cost_center=Global Support - Asia/Pac  \
# 0                             -0.418                                 -0.486
#
#    country=Canada  country=France  country=Singapore  country=South Korea  \
# 0          -0.574           2.319             -0.319               -0.331
#
#    country=United Kingdom  country=United States of America  \
# 0                  -0.418                            -0.585
#
#    ethnicity=American Indian or Alaska Native  ethnicity=Asian  \
# 0                                      -0.241           -0.639
#
#    ethnicity=Black or African American  ethnicity=Hispanic  ethnicity=White  \
# 0                               -0.255              -0.395            1.085
#
#    gender=Female  gender=Male  generation=Baby Boomers (1946-1964)  \
# 0         -1.008        1.008                               -0.288
#
#    generation=Generation X (1965-1980)  \
# 0                               -0.427
#
#    generation=Generation Y/Millenials (1981-1996)  \
# 0                                           0.693
#
#    generation=Generation Z (1997 and onwards)  hiring_source=Agency  \
# 0                                      -0.322                -0.328
#
#    hiring_source=Corporate Website  hiring_source=Internal  \
# 0                            2.008                  -0.324
#
#    hiring_source=Linkedin  hiring_source=Recruiter  hiring_source=Referral  \
# 0                  -0.322                   -0.511                  -0.668
#
#    job_family_group=Development  job_family_group=Executive  \
# 0                        -0.653                      -0.400
#
#    job_family_group=Finance  job_family_group=Sales  \
# 0                    -0.415                   1.608
#
#    job_family_group=Services  job_level=M2  job_level=M3  job_level=M4  \
# 0                     -0.399        -0.117        -0.137        -0.122
#
#    job_level=M5  job_level=M6  job_level=M7  job_level=M8  job_level=M9  \
# 0        -0.118        -0.099        -0.113        -0.196         0.000
#
#    job_level=P1  job_level=P2  job_level=P3  job_level=P4  job_level=P5  \
# 0        -0.252         2.392        -0.564        -0.601        -0.444
#
#    job_profile=Board Management - Executive Vice President  \
# 0                                             -0.132
#
#    job_profile=Board Management - Principal Board Associate  \
# 0                                             -0.159
#
#    job_profile=Board Management - Senior Board Associate  \
# 0                                             -0.226
#
#    job_profile=Board Management - Vice President  \
# 0                                         -0.073
#
#    job_profile=Executive Management - Chief Executive Officer  \
# 0                                              0.000
#
#    job_profile=Executive Management - Executive Vice President  \
# 0                                             -0.137
#
#    job_profile=Executive Management - Principal Operations Executive  \
# 0                                             -0.131
#
#    job_profile=Executive Management - Senior Operations Executive  \
# 0                                             -0.069
#
#    job_profile=Executive Management - Vice President  \
# 0                                             -0.050
#
#    job_profile=FA - Accounting - P2 Accounting Settlement Specialist  \
# 0                                             -0.109
#
#    job_profile=FA - Accounting - P2 Finance Analyst  \
# 0                                            -0.113
#
#    job_profile=FA - Accounting - P3 Accounting Settlement Specialist  \
# 0                                             -0.138
#
#    job_profile=FA - Accounting - P3 Finance Analyst  \
# 0                                            -0.138
#
#    job_profile=FA - Accounting - Principal Accounting Settlement Specialist  \
# 0                                             -0.124
#
#    job_profile=FA - Accounting - Principal Finance Analyst  \
# 0                                             -0.132
#
#    job_profile=FA - Accounting - Senior Accounting Settlement Specialist  \
# 0                                             -0.153
#
#    job_profile=FA - Accounting - Senior Finance Analyst  \
# 0                                             -0.145
#
#    job_profile=FA - Management - Associate Manager  \
# 0                                           -0.039
#
#    job_profile=FA - Management - Director  \
# 0                                  -0.045
#
#    job_profile=FA - Management - Manager  \
# 0                                 -0.047
#
#    job_profile=FA - Management - Senior Director  \
# 0                                         -0.047
#
#    job_profile=FA - Management - Senior Manager  \
# 0                                        -0.039
#
#    job_profile=Human Resources - Associate Manager  \
# 0                                           -0.027
#
#    job_profile=Human Resources - Director  \
# 0                                  -0.032
#
#    job_profile=Human Resources - Manager  \
# 0                                 -0.050
#
#    job_profile=Human Resources - P2 Human Resources Analyst  \
# 0                                             -0.084
#
#    job_profile=Human Resources - P2 Human Resources Consultant  \
# 0                                             -0.093
#
#    job_profile=Human Resources - P3 Human Resources Analyst  \
# 0                                             -0.120
#
#    job_profile=Human Resources - P3 Human Resources Consultant  \
# 0                                             -0.119
#
#    job_profile=Human Resources - Principal Human Resources Analyst  \
# 0                                             -0.082
#
#    job_profile=Human Resources - Principal Human Resources Consultant  \
# 0                                             -0.093
#
#    job_profile=Human Resources - Senior Director  \
# 0                                         -0.022
#
#    job_profile=Human Resources - Senior Human Resources Analyst  \
# 0                                             -0.123
#
#    job_profile=Human Resources - Senior Human Resources Consultant  \
# 0                                             -0.119
#
#    job_profile=Human Resources - Senior Manager  \
# 0                                        -0.042
#
#    job_profile=Human Resources - Vice President  \
# 0                                        -0.022
#
#    job_profile=IT - Product Development - P1 Business Analytics  \
# 0                                             -0.119
#
#    job_profile=IT - Product Development - P1 Data Scientist  \
# 0                                             -0.108
#
#    job_profile=IT - Product Development - P1 QA  \
# 0                                        -0.103
#
#    job_profile=IT - Product Development - P1 Software Engineer  \
# 0                                             -0.110
#
#    job_profile=IT - Product Development - P2 Business Analytics  \
# 0                                             -0.118
#
#    job_profile=IT - Product Development - P2 Data Scientist  \
# 0                                             -0.114
#
#    job_profile=IT - Product Development - P2 QA  \
# 0                                        -0.105
#
#    job_profile=IT - Product Development - P2 Software Engineer  \
# 0                                             -0.120
#
#    job_profile=IT - Product Development - P3 Business Analytics  \
# 0                                             -0.155
#
#    job_profile=IT - Product Development - P3 Data Scientist  \
# 0                                             -0.134
#
#    job_profile=IT - Product Development - P3 QA  \
# 0                                        -0.136
#
#    job_profile=IT - Product Development - P3 Software Engineer  \
# 0                                             -0.140
#
#    job_profile=IT - Product Development - Principal Business Analytics  \
# 0                                             -0.085
#
#    job_profile=IT - Product Development - Principal Data Scientist  \
# 0                                             -0.082
#
#    job_profile=IT - Product Development - Principal QA  \
# 0                                             -0.101
#
#    job_profile=IT - Product Development - Principal Software Engineer  \
# 0                                             -0.082
#
#    job_profile=IT - Product Development - Senior Business Analytics  \
# 0                                             -0.122
#
#    job_profile=IT - Product Development - Senior Data Scientist  \
# 0                                             -0.105
#
#    job_profile=IT - Product Development - Senior QA  \
# 0                                            -0.129
#
#    job_profile=IT - Product Development - Senior Software Engineer  \
# 0                                             -0.121
#
#    job_profile=IT - Product Management - Associate Manager  \
# 0                                             -0.073
#
#    job_profile=IT - Product Management - Director  \
# 0                                          -0.078
#
#    job_profile=IT - Product Management - Executive Vice President  \
# 0                                             -0.039
#
#    job_profile=IT - Product Management - Manager  \
# 0                                         -0.087
#
#    job_profile=IT - Product Management - Senior Director  \
# 0                                             -0.063
#
#    job_profile=IT - Product Management - Senior Manager  \
# 0                                             -0.084
#
#    job_profile=IT - Product Management - Vice President  \
# 0                                             -0.042
#
#    job_profile=Legal - Corporate - Associate Manager  \
# 0                                             -0.016
#
#    job_profile=Legal - Corporate - Manager  \
# 0                                   -0.032
#
#    job_profile=Legal - Corporate - P2 Legal Associate Consultant  \
# 0                                             -0.061
#
#    job_profile=Legal - Corporate - P2 Legal Consultant  \
# 0                                             -0.067
#
#    job_profile=Legal - Corporate - P3 Legal Associate Consultant  \
# 0                                             -0.090
#
#    job_profile=Legal - Corporate - P3 Legal Consultant  \
# 0                                             -0.082
#
#    job_profile=Legal - Corporate - Principal Legal Associate Consultant  \
# 0                                             -0.063
#
#    job_profile=Legal - Corporate - Principal Legal Consultant  \
# 0                                             -0.053
#
#    job_profile=Legal - Corporate - Senior Legal Associate Consultant  \
# 0                                             -0.079
#
#    job_profile=Legal - Corporate - Senior Legal Consultant  \
# 0                                             -0.069
#
#    job_profile=Legal - Corporate - Vice President  \
# 0                                          -0.016
#
#    job_profile=Sales - Direct Sales - P1 Direct Sales Representative  \
# 0                                             -0.084
#
#    job_profile=Sales - Direct Sales - P2 Direct Sales Representative  \
# 0                                             -0.155
#
#    job_profile=Sales - Direct Sales - P3 Direct Sales Representative  \
# 0                                             -0.206
#
#    job_profile=Sales - Direct Sales - Principal Direct Sales Representative  \
# 0                                             -0.145
#
#    job_profile=Sales - Direct Sales - Senior Direct Sales Representative  \
# 0                                             -0.195
#
#    job_profile=Sales - Inside Sales - P1 Inside Sales Representative  \
# 0                                             -0.069
#
#    job_profile=Sales - Inside Sales - P2 Inside Sales Representative  \
# 0                                              6.182
#
#    job_profile=Sales - Inside Sales - P3 Inside Sales Representative  \
# 0                                             -0.208
#
#    job_profile=Sales - Inside Sales - Principal Inside Sales Representative  \
# 0                                             -0.133
#
#    job_profile=Sales - Inside Sales - Senior Inside Sales Representative  \
# 0                                             -0.193
#
#    job_profile=Sales - Management - Associate Manager  \
# 0                                             -0.076
#
#    job_profile=Sales - Management - Director  \
# 0                                     -0.069
#
#    job_profile=Sales - Management - Manager  \
# 0                                    -0.073
#
#    job_profile=Sales - Management - Senior Director  \
# 0                                            -0.055
#
#    job_profile=Sales - Management - Senior Manager  \
# 0                                           -0.067
#
#    job_profile=Sales - Management - Vice President  location=Busan  \
# 0                                           -0.047          -0.136
#
#    location=Calgary  location=Daegu  location=Edmonton  location=Gwangju  \
# 0            -0.158          -0.103             -0.117            -0.076
#
#    location=Incheon  location=London  location=Lyon  location=Marseille  \
# 0            -0.090           -0.418          8.317              -0.158
#
#    location=Montreal  location=New York  location=Nice  location=Paris  \
# 0             -0.203             -0.294         -0.090          -0.323
#
#    location=San Francisco  location=Seoul  location=Singapore  \
# 0                  -0.462          -0.244              -0.319
#
#    location=Toronto  location=Toulouse  location=Vancouver  \
# 0            -0.412             -0.128              -0.159
#
#    management_level=Chief Executive Officer  management_level=Director  \
# 0                                     0.000                     -0.158
#
#    management_level=Executive Vice President  \
# 0                                     -0.215
#
#    management_level=Individual Contributor  management_level=Manager  \
# 0                                    0.526                    -0.239
#
#    management_level=Vice President  region=AMER  region=APAC  region=EMEA  \
# 0                           -0.323       -1.006       -0.486        1.507
#
#    single_job_family=Board Management  single_job_family=Executive Management  \
# 0                              -0.325                                  -0.211
#
#    single_job_family=FA - Accounting  single_job_family=FA - Management  \
# 0                             -0.399                             -0.098
#
#    single_job_family=Human Resources  \
# 0                             -0.324
#
#    single_job_family=IT - Product Development  \
# 0                                      -0.602
#
#    single_job_family=IT - Product Management  \
# 0                                     -0.185
#
#    single_job_family=Legal - Corporate  \
# 0                               -0.210
#
#    single_job_family=Sales - Direct Sales  \
# 0                                  -0.384
#
#    single_job_family=Sales - Inside Sales  \
# 0                                   2.646
#
#    single_job_family=Sales - Management
# 0                                -0.162

# %%
y_test[0:1]
# Out:
# 4506    44500
# Name: total_compensation, dtype: int64

# %%
model.predict(X_test_scaled[0:1, :])
# Out:
# array([40012.98749039])

# %%
model.predict(scaler.transform(X_new_entry))
# Out:
# array([42974.87222143])

# %% [markdown]
# ## Run again Linear Regression only for selected features. Did the feature selection resolves original problem?

# %%
selected_features.index
# Out:
# Index(['job_level=M8', 'age', 'compa_ratio', 'job_level=M7', 'is_leader',
#        'region=AMER', 'job_level=P3', 'job_level=M6',
#        'generation=Baby Boomers (1946-1964)',
#        'cost_center=Global Support - Asia/Pac', 'job_level=M4'],
#       dtype='object')

# %%
model = sklearn.linear_model.LinearRegression()
model.fit(pd.DataFrame(X_train_scaled, columns=X_train.columns)[selected_features.index], y_train)
y_pred = model.predict(pd.DataFrame(X_test_scaled, columns=X_test.columns)[selected_features.index])
residuals = y_test - y_pred

# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = sklearn.metrics.r2_score(y_test, y_pred)
mape = sklearn.metrics.mean_absolute_percentage_error(y_test, y_pred)

print("Mean Absolute Percentage Error (MAPE):", mape)
print("Root Mean Squared Error:", rmse)
print("R-squared:", r2)
# Out:
# Mean Absolute Percentage Error (MAPE): 0.12508973808636573
# Root Mean Squared Error: 25115.239688206973
# R-squared: 0.9406872778959969

# %% [markdown]
# # 3) Random Forest and Boruta feature selection

# %% [markdown]
# * https://medium.com/geekculture/boruta-feature-selection-explained-in-python-7ae8bf4aa1e7

# %%
# Install package not available in Colab by default
# !pip install boruta

# %% [markdown]
# ### Specify a base RF model and use it to run Boruta feature selection

# %%
from boruta import BorutaPy

# %%
# Base RF model specification
rf = sklearn.ensemble.RandomForestRegressor(max_depth=20, random_state=123)

# %%
# Boruta feature search
feat_selector = BorutaPy(
    verbose=2,
    estimator=rf,
    n_estimators=20,
    max_iter=25,
    random_state=123
)

feat_selector.fit(np.array(X_train), np.array(y_train))
# Out:
# Iteration: 	1 / 25
# Confirmed: 	0
# Tentative: 	185
# Rejected: 	0
# Iteration: 	2 / 25
# Confirmed: 	0
# Tentative: 	185
# Rejected: 	0
# Iteration: 	3 / 25
# Confirmed: 	0
# Tentative: 	185
# Rejected: 	0
# Iteration: 	4 / 25
# Confirmed: 	0
# Tentative: 	185
# Rejected: 	0
# Iteration: 	5 / 25
# Confirmed: 	0
# Tentative: 	185
# Rejected: 	0
# Iteration: 	6 / 25
# Confirmed: 	0
# Tentative: 	185
# Rejected: 	0
# Iteration: 	7 / 25
# Confirmed: 	0
# Tentative: 	185
# Rejected: 	0
# Iteration: 	8 / 25
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	158
# Iteration: 	9 / 25
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	158
# Iteration: 	10 / 25
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	158
# Iteration: 	11 / 25
# Confirmed: 	22
# Tentative: 	5
# Rejected: 	158
# Iteration: 	12 / 25
# Confirmed: 	22
# Tentative: 	3
# Rejected: 	160
# Iteration: 	13 / 25
# Confirmed: 	22
# Tentative: 	3
# Rejected: 	160
# Iteration: 	14 / 25
# Confirmed: 	22
# Tentative: 	3
# Rejected: 	160
# Iteration: 	15 / 25
# Confirmed: 	22
# Tentative: 	3
# Rejected: 	160
# Iteration: 	16 / 25
# Confirmed: 	22
# Tentative: 	3
# Rejected: 	160
# Iteration: 	17 / 25
# Confirmed: 	22
# Tentative: 	3
# Rejected: 	160
# Iteration: 	18 / 25
# Confirmed: 	22
# Tentative: 	3
# Rejected: 	160
# Iteration: 	19 / 25
# Confirmed: 	22
# Tentative: 	1
# Rejected: 	162
# Iteration: 	20 / 25
# Confirmed: 	22
# Tentative: 	1
# Rejected: 	162
# Iteration: 	21 / 25
# Confirmed: 	22
# Tentative: 	1
# Rejected: 	162
# Iteration: 	22 / 25
# Confirmed: 	23
# Tentative: 	0
# Rejected: 	162
#
#
# BorutaPy finished running.
#
# Iteration: 	23 / 25
# Confirmed: 	23
# Tentative: 	0
# Rejected: 	162
# BorutaPy(estimator=RandomForestRegressor(max_depth=20, n_estimators=20,
#                                          random_state=RandomState(MT19937) at 0x184E1E5C740),
#          max_iter=25, n_estimators=20,
#          random_state=RandomState(MT19937) at 0x184E1E5C740, verbose=2)

# %%
# Get the list of selected features
boruta_selected = []

for i in range(len(feat_selector.support_)):
    if (feat_selector.support_[i] or feat_selector.support_weak_[i]):
        boruta_selected.append(X_train.columns[i])
        print(X_train.columns[i])
# Out:
# compa_ratio
# is_leader
# is_manager
# age
# cost_center=Global Support - Asia/Pac
# job_level=M4
# job_level=M5
# job_level=M6
# job_level=M7
# job_level=M8
# job_level=P1
# job_level=P2
# job_level=P3
# job_level=P4
# job_level=P5
# job_profile=Executive Management - Executive Vice President
# job_profile=Executive Management - Vice President
# management_level=Director
# management_level=Executive Vice President
# management_level=Vice President
# region=AMER
# region=APAC
# region=EMEA

# %%
print('Number of selected features: ', len(boruta_selected))

# %% [markdown]
# ### Run RF model with features selected by Boruta

# %%
# Get subsets of explanatory variables only with features that were selected
X_filtered_train = X_train[boruta_selected]
X_filtered_test = X_test[boruta_selected]

# %%
# Model specification 
rf = sklearn.ensemble.RandomForestRegressor(n_estimators=50, max_depth=20, random_state=123)

# Fit the model
rf.fit(X_filtered_train, y_train)

# Get predictions
y_pred_BR_sel = rf.predict(X_filtered_test)

# %%
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = sklearn.metrics.r2_score(y_test, y_pred_BR_sel)
mape = sklearn.metrics.mean_absolute_percentage_error(y_test, y_pred_BR_sel)
print("Mean Absolute Percentage Error (MAPE):", mape)
print("Root Mean Squared Error:", rmse)
print("R-squared:", r2)
# Out:
# Mean Absolute Percentage Error (MAPE): 0.004961502884308441
# Root Mean Squared Error: 25115.239688206973
# R-squared: 0.9948534486445018

# %% [markdown]
# ### Run RF model with all features

# %%
# Model specification 
rf = sklearn.ensemble.RandomForestRegressor(n_estimators=50, max_depth=20, random_state=123)

# Fit the model
rf.fit(X_train, y_train)

# Get predictions
y_pred_rf = rf.predict(X_test)

# %%
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = sklearn.metrics.r2_score(y_test, y_pred_rf)
mape = sklearn.metrics.mean_absolute_percentage_error(y_test, y_pred_rf)
print("Mean Absolute Percentage Error (MAPE):", mape)
print("Root Mean Squared Error:", rmse)
print("R-squared:", r2)
# Out:
# Mean Absolute Percentage Error (MAPE): 0.006767382522046515
# Root Mean Squared Error: 25115.239688206973
# R-squared: 0.994024978604095

# %% [markdown]
# # Tasks
# ## Task 1: Use a *feature_importance* param in Random Forest (RF) for feature selection
# 1. Fit RF model without feature selection
# 2. Select the most important features using variable importance scores
#     - Visualize the value of *feature_importance* for attributes
# 3. Fit the RF model again, now with selected features only
#
# ## Task 2: Summarize the insights gained in this analysis
# Try some other regression model. You can choose different algorithm or different parameters.
#
# Create a conlusion for this analysis. You can write about something from following list:
# - Report the prediction scores achived by various models.
# - What features were found important when solving this regression task?
#
# Imagine, you are presenting these results to HR deparment team. Did you get any relevant information for that presentation in this analysis?

# %%
from sklearn.ensemble import RandomForestRegressor

rf_without_selection = RandomForestRegressor(n_estimators=50, max_depth=20, random_state = 123)
rf_without_selection.fit(X_train,y_train)

y_pred_without_selection = rf_without_selection.predict(X_test)

# %%
from sklearn.metrics import r2_score, mean_absolute_percentage_error

mse = mean_squared_error(y_test,y_pred_without_selection)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred_without_selection)
mape = mean_absolute_percentage_error(y_test, y_pred_without_selection)

print("=== Model bez výberu atribútov ===")
print("RMSE:", round(rmse, 3))
print("R²:", round(r2, 3))
print("MAPE:", round(mape, 3))
# Out:
# === Model bez výberu atribútov ===
# RMSE: 7971.373
# R²: 0.994
# MAPE: 0.007

# %%
importances = pd.Series(rf_without_selection.feature_importances_, index = X_train.columns).sort_values(ascending=False)

# %%
plt.figure(figsize=(10,5))
importances.head(10).plot(kind = "bar", color = "cornflowerblue")
plt.title("Feature importance (random forest)")
plt.ylabel("importance score")
plt.show()

# %%
top_features = importances.head(8).index
print("top features selected", list(top_features))
# Out:
# top features selected ['is_leader', 'age', 'management_level=Director', 'region=AMER', 'compa_ratio', 'job_level=M8', 'job_level=M7', 'job_profile=Executive Management - Vice President']

# %%
X_train_top = X_train[top_features]
X_test_top  = X_test[top_features]

rf_top = RandomForestRegressor(n_estimators=50, max_depth= 20, random_state= 123)
rf_top.fit(X_train_top, y_train)

y_pred_top = rf_top.predict(X_test_top)

mse = mean_squared_error(y_test,y_pred_top)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred_top)
mape = mean_absolute_percentage_error(y_test, y_pred_top)

print("=== Model len s top atribútmi ===")
print("RMSE:", round(rmse, 3))
print("R²:", round(r2, 3))
print("MAPE:", round(mape, 3))
# Out:
# === Model len s top atribútmi ===
# RMSE: 12623.066
# R²: 0.985
# MAPE: 0.049

# %%
from sklearn.ensemble import GradientBoostingRegressor

gbr = GradientBoostingRegressor(random_state = 123)
gbr.fit(X_train, y_train)
y_pred_gbr = gbr.predict(X_test)

# %%
models = "Gradient Boosting"
r2_scores = r2_score(y_test, y_pred_gbr)
mse = mean_squared_error(y_test, y_pred_gbr)
rmse = np.sqrt(mse)
mape_scores = mean_absolute_percentage_error(y_test, y_pred_gbr)

# %%
print("=== Model len s top atribútmi ===")
print("RMSE:", round(rmse, 3))
print("R²:", round(r2_scores, 3))
print("MAPE:", round(mape, 3))
# Out:
# === Model len s top atribútmi ===
# RMSE: 9452.398
# R²: 0.992
# MAPE: 0.049

# %% [markdown]
# ###  Model Performance
#
# Two regression algorithms were compared:
#
# | Model | RMSE | R*R | MAPE |
# |--------|------|------|------|
# | Random Forest (all features) | **7971.37** | **0.994** | **0.007** |
# | Random Forest (top 8 features) | **12623.07** | **0.985** | **0.049** |
# | Gradient Boosting (top features) | **9452.40** | **0.992** | **0.049** |
#
# The **Random Forest** model achieved the highest accuracy overall, with an **R*R of 0.994**, meaning it explains **99.4% of the variance** in the target variable.
# The **Gradient Boosting Regressor** showed slightly lower but still very strong performance, confirming the reliability of the results.
# Even after feature selection (using the **top 8 most important variables**), the model retained high predictive power, which indicates that these features capture most of the information in the dataset.

# %% [markdown]
# ###  Feature Importance Insights
#
# The **Random Forest** model revealed the most important predictors:
#
# - **is_leader** – leadership status had the strongest influence on predictions
# - **age** – age also showed a notable impact
# - **management_level = Director** and **job_level (M7–M8)** – higher job positions were predictive
# - **region = AMER** and **compa_ratio** – regional and compensation-related variables contributed moderately
#
# These variables appear to be strong indicators of employee performance, seniority, or compensation trends — valuable insights for **HR analytics**.
